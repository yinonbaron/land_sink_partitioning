# %%
import cdsapi
import ee
ee.Authenticate()
ee.Initialize()
import geemap
import xarray as xr

import pandas as pd
from glob import glob
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# The aim of this script is to download all of the necessary input data for the analysis. An archived version of the data is available at the following link: #TODO
# The only data source which is not publicly available is the L-VOD data, which is available upon request from the authors of the paper.
#
# The data contains the following categories:
#
# 1. Land use data
# 2. Countries data
# 3. Biomass data
# 4. Aboveground to belowground biomass ratio data
# 5. Carbon budget data
# 6. Data for supplementary analyses

# %% [markdown]
# # 1. Land use data

# %% [markdown]
# ## ESA CCI Land Cover data
# from:
# https://cds.climate.copernicus.eu/cdsapp#!/dataset/satellite-land-cover?tab=overview
#
# first follow these directions to set up the API key for CDS: https://cds.climate.copernicus.eu/how-to-api

# %% [markdown]
# ### Download files

# %%
c = cdsapi.Client()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# retrieve 1992-2001 land cover data from ESA CCI
dataset = "satellite-land-cover"
request = {
    "variable": "all",
    "year": [
        "1992", "1993", "1994",
        "1995", "1996", "1997",
        "1998", "1999", "2000",
        "2001"
    ],
    "version": ["v2_0_7cds"],
    'data_format': 'zip'
}
target = '../data/land_cover/ESA_CCI/1992-2001.zip'

c.retrieve(dataset, request, target).download()

# %%
# retrieve 2002-2011 land cover data from ESA CCI
dataset = "satellite-land-cover"
request = {
    "variable": "all",
    "year": [
        '2002', '2003', '2004',
        '2005', '2006', '2007',
        '2008', '2009', '2010',
        '2011'
    ],
    "version": ["v2_0_7cds"],
    'data_format': 'zip'
}
target = '../data/land_cover/ESA_CCI/2002-2011.zip'

c.retrieve(dataset, request, target).download()

# %%
# retrieve 2012-2015 land cover data from ESA CCI
dataset = "satellite-land-cover"
request = {
    "variable": "all",
    "year": [
            '2012', '2013', '2014',
            '2015'
            ],
    "version": ["v2_0_7cds"],
    'data_format': 'zip'
}
target = '../data/land_cover/ESA_CCI/2012-2015.zip'

c.retrieve(dataset, request, target).download()

# %%
# retrieve 2016-2020 land cover data from ESA CCI
dataset = "satellite-land-cover"
request = {
    "variable": "all",
    "year": [
        "2016", "2017", "2018",
        "2019", "2020"
    ],
    "version": ["v2_1_1"]
}

target = '../data/land_cover/ESA_CCI/2016-2020.zip'

c.retrieve(dataset, request, target).download()

# %% [markdown]
# ### Unzip files

# %%
zips = glob('../data/land_cover/ESA_CCI/*.zip')
for z in zips:
    # !unzip -o {z} -d ../data/land_cover/ESA_CCI/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Archive:  ../data/land_cover/ESA_CCI/466641c5a8fc29a0bb1024ef328964b8.zip
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2002-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2003-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2004-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2005-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2006-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2007-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2008-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2009-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2010-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2011-v2.0.7cds.nc
# Archive:  ../data/land_cover/ESA_CCI/e9dd74dba98d7e2ab489e0172d44be1c.zip
#   inflating: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2016-v2.1.1.nc
#   inflating: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2017-v2.1.1.nc
#   inflating: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2018-v2.1.1.nc
#   inflating: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2019-v2.1.1.nc
#   inflating: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2020-v2.1.1.nc
# Archive:  ../data/land_cover/ESA_CCI/428a26f1592dfca102d4a488e02c964.zip
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1992-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1993-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1994-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1995-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1996-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1997-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1998-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1999-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2000-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2001-v2.0.7cds.nc
# Archive:  ../data/land_cover/ESA_CCI/4d647f96675e25cc1ba006ef7f39964e.zip
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2012-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2013-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2014-v2.0.7cds.nc
#   inflating: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2015-v2.0.7cds.nc

# %%
# !unzip ../data/land_cover/ESA_CCI/1992-2001.zip -d ../data/land_cover/ESA_CCI/
# Out:
# Archive:  ../data/land_cover/ESA_CCI/1992-2001.zip
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1994-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2001-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1992-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1999-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1996-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1998-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1995-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2000-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1993-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1997-v2.0.7cds.nc

# %%
# !unzip ../data/land_cover/ESA_CCI/2002-2011.zip -d ../data/land_cover/ESA_CCI/
# Out:
# Archive:  ../data/land_cover/ESA_CCI/2002-2011.zip
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2009-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2003-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2011-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2006-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2004-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2010-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2008-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2005-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2002-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2007-v2.0.7cds.nc

# %%
# !unzip ../data/land_cover/ESA_CCI/2016-2020.zip -d ../data/land_cover/ESA_CCI/
# Out:
# Archive:  ../data/land_cover/ESA_CCI/2016-2020.zip
#  extracting: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2018-v2.1.1.nc
#  extracting: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2020-v2.1.1.nc
#  extracting: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2016-v2.1.1.nc
#  extracting: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2019-v2.1.1.nc
#  extracting: ../data/land_cover/ESA_CCI/C3S-LC-L4-LCCS-Map-300m-P1Y-2017-v2.1.1.nc

# %%
# !unzip ../data/land_cover/ESA_CCI/2012-2015.zip -d ../data/land_cover/ESA_CCI/
# Out:
# Archive:  ../data/land_cover/ESA_CCI/2012-2015.zip
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2012-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2014-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2013-v2.0.7cds.nc
#  extracting: ../data/land_cover/ESA_CCI/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2015-v2.0.7cds.nc

# %% [markdown]
# ## Song et al. (2018)
#
# Download from https://lpdaac.usgs.gov/products/vcf5kyrv001/
#
# Run the data/land_cover/song_et_al_2018/4839310647-download.sh script
#
# ```bash
# cd data/land_cover/song_et_al_2018
# bash 4839310647-download.sh
# cd ../../../
# ```

# %% [markdown]
# ## Xu et al. (2021)

# %%
# !wget https://zenodo.org/records/4161694/files/deforestation_emission_0119_v2_inTg.tif?download=1 -O ../data/land_cover/xu_et_al_2021/deforestation_emission_0119_v2_inTg.tif
# !wget https://zenodo.org/records/4161694/files/degradation_emission_0119_v2_inTg.tif?download=1 -O ../data/land_cover/xu_et_al_2021/degradation_emission_0119_v2_inTg.tif
# !wget https://zenodo.org/records/4161694/files/fireforest_emission_0119_v2_inTg.tif?download=1 -O ../data/land_cover/xu_et_al_2021/fireforest_emission_0119_v2_inTg.tif
# !wget https://zenodo.org/records/4161694/files/firenonforest_emission_0119_v2_inTg.tif?download=1 -O ../data/land_cover/xu_et_al_2021/firenonforest_emission_0119_v2_inTg.tif
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 07:59:52--  https://zenodo.org/records/4161694/files/deforestation_emission_0119_v2_inTg.tif?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75823677 (72M) [image/tiff]
# Saving to: ‘../data/land_cover/xu_et_al_2021/deforestation_emission_0119_v2_inTg.tif’
#
# ../data/land_cover/ 100%[===================>]  72.31M  43.3MB/s    in 1.7s
#
# 2025-03-04 07:59:54 (43.3 MB/s) - ‘../data/land_cover/xu_et_al_2021/deforestation_emission_0119_v2_inTg.tif’ saved [75823677/75823677]
#
# --2025-03-04 07:59:55--  https://zenodo.org/records/4161694/files/degradation_emission_0119_v2_inTg.tif?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26166219 (25M) [image/tiff]
# Saving to: ‘../data/land_cover/xu_et_al_2021/degradation_emission_0119_v2_inTg.tif’
#
# ../data/land_cover/ 100%[===================>]  24.95M  27.2MB/s    in 0.9s
#
# 2025-03-04 07:59:56 (27.2 MB/s) - ‘../data/land_cover/xu_et_al_2021/degradation_emission_0119_v2_inTg.tif’ saved [26166219/26166219]
#
# --2025-03-04 07:59:56--  https://zenodo.org/records/4161694/files/fireforest_emission_0119_v2_inTg.tif?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9501695 (9.1M) [image/tiff]
# Saving to: ‘../data/land_cover/xu_et_al_2021/fireforest_emission_0119_v2_inTg.tif’
#
# ../data/land_cover/ 100%[===================>]   9.06M  16.1MB/s    in 0.6s
#
# 2025-03-04 07:59:57 (16.1 MB/s) - ‘../data/land_cover/xu_et_al_2021/fireforest_emission_0119_v2_inTg.tif’ saved [9501695/9501695]
#
# --2025-03-04 07:59:57--  https://zenodo.org/records/4161694/files/firenonforest_emission_0119_v2_inTg.tif?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24872204 (24M) [image/tiff]
# Saving to: ‘../data/land_cover/xu_et_al_2021/firenonforest_emission_0119_v2_inTg.tif’
#
# ../data/land_cover/ 100%[===================>]  23.72M  28.3MB/s    in 0.8s
#
# 2025-03-04 07:59:58 (28.3 MB/s) - ‘../data/land_cover/xu_et_al_2021/firenonforest_emission_0119_v2_inTg.tif’ saved [24872204/24872204]

# %% [markdown]
# # 2. Country data

# %% [markdown]
# ## Natural Earth

# %%
# get country boundaries from natural earth
# !wget https://naciscdn.org/naturalearth/packages/natural_earth_vector.zip -O ../data/country_data/natural_earth_vector.zip
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 08:00:04--  https://naciscdn.org/naturalearth/packages/natural_earth_vector.zip
# Resolving naciscdn.org (naciscdn.org)... 3.160.196.78, 3.160.196.121, 3.160.196.77, ...
# Connecting to naciscdn.org (naciscdn.org)|3.160.196.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 587029538 (560M) [application/zip]
# Saving to: ‘../data/country_data/natural_earth_vector.zip’
#
# ../data/country_dat 100%[===================>] 559.83M  69.9MB/s    in 8.3s
#
# 2025-03-04 08:00:13 (67.7 MB/s) - ‘../data/country_data/natural_earth_vector.zip’ saved [587029538/587029538]

# %%
# !unzip -o ../data/country_data/natural_earth_vector.zip -d ../data/country_data/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Archive:  ../data/country_data/natural_earth_vector.zip
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claim_limit_lines.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claim_limit_lines.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claim_limit_lines.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claim_limit_lines.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claim_limit_lines.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claim_limit_lines.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claims.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claims.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claims.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claims.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claims.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_antarctic_claims.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_disputed_areas.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_disputed_areas.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_disputed_areas.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_disputed_areas.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_disputed_areas.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_disputed_areas.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_land.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_land.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_land.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_land.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_land.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_land.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_land.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_map_units.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_map_units.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_map_units.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_map_units.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_map_units.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_map_units.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_lakes.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_lakes.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_lakes.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_lakes.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_lakes.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_lakes.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_lakes.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas_scale_rank_minor_islands.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas_scale_rank_minor_islands.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas_scale_rank_minor_islands.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas_scale_rank_minor_islands.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas_scale_rank_minor_islands.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas_scale_rank_minor_islands.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_disputed_areas_scale_rank_minor_islands.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_label_points.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_label_points.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_label_points.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_label_points.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_label_points.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_label_points.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_map_subunits.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_subunits.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_subunits.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_subunits.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_subunits.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_subunits.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_map_subunits.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_map_units.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_units.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_units.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_units.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_units.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_map_units.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_map_units.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_pacific_groupings.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_pacific_groupings.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_pacific_groupings.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_pacific_groupings.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_pacific_groupings.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_pacific_groupings.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank_minor_islands.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank_minor_islands.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank_minor_islands.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank_minor_islands.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank_minor_islands.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank_minor_islands.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_scale_rank_minor_islands.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_seams.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_seams.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_seams.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_seams.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_seams.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_seams.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_sovereignty.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_sovereignty.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_sovereignty.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_sovereignty.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_sovereignty.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_sovereignty.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_sovereignty.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points_details.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points_details.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points_details.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points_details.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points_details.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points_details.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_seams.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_seams.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_seams.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_seams.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_seams.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_seams.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lakes.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lakes.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lakes.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lakes.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lakes.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lakes.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lakes.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lines.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lines.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lines.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lines.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lines.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lines.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_lines.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_scale_rank.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_scale_rank.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_scale_rank.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_scale_rank.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_scale_rank.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_scale_rank.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_1_states_provinces_scale_rank.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_airports.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_airports.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_airports.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_airports.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_airports.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_airports.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_area.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_area.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_area.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_area.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_area.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_area.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_line.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_line.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_line.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_line.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_line.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_line.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_point.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_point.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_point.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_point.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_point.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_point.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_scale_rank.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_scale_rank.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_scale_rank.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_scale_rank.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_scale_rank.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_parks_and_protected_lands_scale_rank.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_populated_places.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_populated_places.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places_simple.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places_simple.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places_simple.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places_simple.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_populated_places_simple.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_populated_places_simple.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_ports.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_ports.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_ports.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_ports.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_ports.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_ports.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_railroads.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads_north_america.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads_north_america.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads_north_america.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads_north_america.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_railroads_north_america.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_railroads_north_america.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_roads.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads_north_america.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads_north_america.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads_north_america.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads_north_america.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_roads_north_america.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_roads_north_america.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_time_zones.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_time_zones.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_time_zones.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_time_zones.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_time_zones.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_time_zones.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_urban_areas.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas_landscan.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas_landscan.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas_landscan.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas_landscan.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_urban_areas_landscan.shx
#  extracting: ../data/country_data/10m_cultural/ne_10m_urban_areas_landscan.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_lines.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_lines.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_lines.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_lines.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_lines.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_lines.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_polys.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_polys.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_polys.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_polys.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_polys.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_antarctic_ice_shelves_polys.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_A_10000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_A_10000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_A_10000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_A_10000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_A_10000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_A_10000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_B_9000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_B_9000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_B_9000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_B_9000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_B_9000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_B_9000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_C_8000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_C_8000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_C_8000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_C_8000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_C_8000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_C_8000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_D_7000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_D_7000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_D_7000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_D_7000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_D_7000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_D_7000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_E_6000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_E_6000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_E_6000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_E_6000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_E_6000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_E_6000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_F_5000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_F_5000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_F_5000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_F_5000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_F_5000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_F_5000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_G_4000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_G_4000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_G_4000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_G_4000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_G_4000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_G_4000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_H_3000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_H_3000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_H_3000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_H_3000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_H_3000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_H_3000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_I_2000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_I_2000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_I_2000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_I_2000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_I_2000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_I_2000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_J_1000.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_J_1000.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_J_1000.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_J_1000.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_J_1000.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_J_1000.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_K_200.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_K_200.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_K_200.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_K_200.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_K_200.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_K_200.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_L_0.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_L_0.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_L_0.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_L_0.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_L_0.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_bathymetry_all/ne_10m_bathymetry_L_0.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_coastline.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_coastline.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_coastline.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_coastline.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_coastline.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_coastline.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_geographic_lines.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_geographic_lines.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_geographic_lines.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_geographic_lines.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_geographic_lines.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_geographic_lines.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_marine_polys.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_marine_polys.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_marine_polys.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_marine_polys.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_marine_polys.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_geography_marine_polys.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_elevation_points.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_elevation_points.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_elevation_points.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_elevation_points.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_elevation_points.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_geography_regions_elevation_points.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_points.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_points.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_points.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_points.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_points.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_geography_regions_points.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_polys.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_polys.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_polys.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_polys.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_geography_regions_polys.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_geography_regions_polys.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_glaciated_areas.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_glaciated_areas.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_glaciated_areas.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_glaciated_areas.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_glaciated_areas.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_glaciated_areas.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_1.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_1.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_1.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_1.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_1.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_1.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_10.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_10.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_10.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_10.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_10.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_10.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_15.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_15.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_15.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_15.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_15.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_15.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_20.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_20.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_20.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_20.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_20.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_20.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_30.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_30.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_30.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_30.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_30.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_30.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_5.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_5.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_5.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_5.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_5.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_graticules_5.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_wgs84_bounding_box.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_wgs84_bounding_box.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_wgs84_bounding_box.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_wgs84_bounding_box.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_wgs84_bounding_box.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_graticules_all/ne_10m_wgs84_bounding_box.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_lakes.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_europe.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_europe.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_europe.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_europe.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_europe.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_lakes_europe.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_historic.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_historic.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_historic.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_historic.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_historic.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_lakes_historic.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_north_america.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_north_america.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_north_america.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_north_america.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_north_america.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_lakes_north_america.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_pluvial.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_pluvial.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_pluvial.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_pluvial.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_pluvial.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_lakes_pluvial.VERSION.txt
#  extracting: ../data/country_data/10m_physical/ne_10m_land.cpg
#   inflating: ../data/country_data/10m_physical/ne_10m_land.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_land.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_land.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_land.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_land.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_land.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_label_points.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_label_points.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_label_points.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_label_points.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_label_points.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_land_ocean_label_points.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_seams.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_seams.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_seams.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_seams.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_land_ocean_seams.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_land_ocean_seams.VERSION.txt
#  extracting: ../data/country_data/10m_physical/ne_10m_land_scale_rank.cpg
#   inflating: ../data/country_data/10m_physical/ne_10m_land_scale_rank.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_land_scale_rank.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_land_scale_rank.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_land_scale_rank.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_land_scale_rank.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_land_scale_rank.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_minor_islands.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_coastline.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_coastline.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_coastline.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_coastline.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_coastline.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_minor_islands_coastline.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_label_points.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_label_points.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_label_points.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_label_points.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_minor_islands_label_points.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_minor_islands_label_points.VERSION.txt
#  extracting: ../data/country_data/10m_physical/ne_10m_ocean.cpg
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_ocean.VERSION.txt
#  extracting: ../data/country_data/10m_physical/ne_10m_ocean_scale_rank.cpg
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean_scale_rank.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean_scale_rank.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean_scale_rank.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean_scale_rank.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_ocean_scale_rank.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_ocean_scale_rank.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_playas.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_playas.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_playas.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_playas.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_playas.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_playas.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_reefs.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_reefs.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_reefs.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_reefs.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_reefs.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_reefs.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_europe.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_europe.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_europe.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_europe.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_europe.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_rivers_europe.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines_scale_rank.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_lake_centerlines_scale_rank.prj
# ...
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_prt.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_isr.shp
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_lakes.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_2_counties.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ukr.README.html
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_pol.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_bdg.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_usa.README.html
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_prt.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_scale_rank.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_nld.shp
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_chn.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_label_points.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_fra.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_usa.dbf
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_gbr.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_esp.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ukr.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_bdg.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ita.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_label_points_details.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_nld.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_scale_rank_minor_islands.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_mar.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator_chn.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_kor.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_rus.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_mar.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_label_points.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_scale_rank_minor_islands.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_sau.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_mar.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_usa.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_rus.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_deu.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ukr.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ita.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_bdg.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_chn.prj
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_grc.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_pse.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_swe.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_label_points.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_mar.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_nld.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_lines.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_scale_rank_minor_islands.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_lakes.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_rus.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_usa.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_scale_rank_minor_islands.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_bdg.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ita.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_isr.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ukr.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_kor.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_twn.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_prt.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_isr.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_deu.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_grc.prj
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_fra.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_to_match.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_egy.README.html
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_pak.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_vnm.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_pol.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_gbr.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_scale_rank.dbf
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tur.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_boundary_lines_maritime_indicator_chn.dbf
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_bra.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_jpn.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_vnm.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tur.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_nld.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_twn.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_egy.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_1_label_points_details.README.html
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_deu.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_to_match.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_ita.README.html
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_jpn.VERSION.txt
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_2_counties_to_match.cpg
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_gbr.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_sau.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_pol.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_esp.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_idn.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_arg.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_twn.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_jpn.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tur.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_vnm.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_pse.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_australia.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_australia.dbf
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_australia.README.html
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_australia.shx
#  extracting: ../data/country_data/10m_physical/ne_10m_rivers_australia.cpg
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_australia.shp
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_australia.prj
#  extracting: ../data/country_data/10m_physical/ne_10m_lakes_australia.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_australia.dbf
#  extracting: ../data/country_data/10m_physical/ne_10m_rivers_australia.VERSION.txt
#   inflating: ../data/country_data/10m_physical/ne_10m_rivers_australia.prj
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_australia.shp
#  extracting: ../data/country_data/10m_physical/ne_10m_lakes_australia.cpg
#   inflating: ../data/country_data/10m_physical/ne_10m_lakes_australia.shx
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_1_seams.shp
#  extracting: ../data/country_data/50m_cultural/ne_50m_admin_1_seams.cpg
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_0_boundary_lines_maritime_indicator_chn.shp
#  extracting: ../data/country_data/50m_cultural/ne_50m_admin_0_boundary_lines_maritime_indicator_chn.cpg
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_1_seams.shx
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_0_boundary_lines_maritime_indicator_chn.shx
#   inflating: ../data/country_data/50m_cultural/ne_10m_admin_1_sel.shp
#  extracting: ../data/country_data/50m_cultural/ne_10m_admin_1_sel.cpg
#   inflating: ../data/country_data/50m_cultural/ne_10m_admin_1_sel.shx
#   inflating: ../data/country_data/50m_cultural/ne_10m_admin_1_sel.dbf
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_0_boundary_lines_maritime_indicator_chn.README.html
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_1_seams.dbf
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_0_boundary_lines_maritime_indicator_chn.dbf
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_1_seams.prj
#   inflating: ../data/country_data/50m_cultural/ne_50m_admin_0_boundary_lines_maritime_indicator_chn.prj
#   inflating: ../data/country_data/50m_cultural/ne_10m_admin_1_sel.prj
#  extracting: ../data/country_data/50m_cultural/ne_50m_admin_0_boundary_lines_maritime_indicator_chn.VERSION.txt
#   inflating: ../data/country_data/housekeeping/ne_admin_0_details_huh.ods
#    creating: ../data/country_data/tools/457_fix_wikidataids/
#   inflating: ../data/country_data/tools/457_fix_wikidataids/ne_10m_populated_places_modified.prj
#   inflating: ../data/country_data/tools/457_fix_wikidataids/ne_10m_populated_places_modified_metadata.csv
#   inflating: ../data/country_data/tools/457_fix_wikidataids/Fix_10m_Populated_Places_WikidataIDs.R
#   inflating: ../data/country_data/tools/457_fix_wikidataids/coords.to.check.csv
#   inflating: ../data/country_data/tools/457_fix_wikidataids/ne_10m_populated_places_modified.shx
#  extracting: ../data/country_data/tools/457_fix_wikidataids/ne_10m_populated_places_modified.cpg
#   inflating: ../data/country_data/tools/457_fix_wikidataids/ne_10m_populated_places_modified.shp
#   inflating: ../data/country_data/tools/457_fix_wikidataids/ne_10m_populated_places_modified.dbf
#    creating: ../data/country_data/tools/510_swap_wikidataids/
#   inflating: ../data/country_data/tools/510_swap_wikidataids/ne_10m_populated_places_modified.prj
#   inflating: ../data/country_data/tools/510_swap_wikidataids/ne_10m_populated_places_modified_metadata.csv
#   inflating: ../data/country_data/tools/510_swap_wikidataids/Update_10m_Populated_Places_Swap_WikidataIDs.R
#   inflating: ../data/country_data/tools/510_swap_wikidataids/coords.to.check.csv
#   inflating: ../data/country_data/tools/510_swap_wikidataids/ne_10m_populated_places_modified.shx
#  extracting: ../data/country_data/tools/510_swap_wikidataids/ne_10m_populated_places_modified.cpg
#   inflating: ../data/country_data/tools/510_swap_wikidataids/ne_10m_populated_places_modified.shp
#   inflating: ../data/country_data/tools/510_swap_wikidataids/ne_10m_populated_places_modified.dbf
#    creating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/
#   inflating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/ne_10m_populated_places_modified.prj
#   inflating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/ne_10m_populated_places_modified_metadata.csv
#   inflating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/coords.to.check.csv
#   inflating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/ne_10m_populated_places_modified.shx
#   inflating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/Update_10m_Populated_Places_Metadata.R
#  extracting: ../data/country_data/tools/508_fix_10m_populated_places_metadata/ne_10m_populated_places_modified.cpg
#   inflating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/ne_10m_populated_places_modified.shp
#   inflating: ../data/country_data/tools/508_fix_10m_populated_places_metadata/ne_10m_populated_places_modified.dbf
#   inflating: ../data/country_data/tools/wikidata/.DS_Store
#   inflating: ../data/country_data/tools/wikidata/x_tempshape/.DS_Store
#    creating: ../data/country_data/tools/515_extreme_distance_candidates/
#   inflating: ../data/country_data/tools/515_extreme_distance_candidates/Update_extreme_distance_candidates.R
#   inflating: ../data/country_data/tools/515_extreme_distance_candidates/ne_10m_populated_places_modified.prj
#   inflating: ../data/country_data/tools/515_extreme_distance_candidates/ne_10m_populated_places_modified_metadata.csv
#   inflating: ../data/country_data/tools/515_extreme_distance_candidates/coords.to.check.csv
#   inflating: ../data/country_data/tools/515_extreme_distance_candidates/ne_10m_populated_places_modified.shx
#  extracting: ../data/country_data/tools/515_extreme_distance_candidates/ne_10m_populated_places_modified.cpg
#   inflating: ../data/country_data/tools/515_extreme_distance_candidates/ne_10m_populated_places_modified.shp
#   inflating: ../data/country_data/tools/515_extreme_distance_candidates/ne_10m_populated_places_modified.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_iso.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_iso.shp
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tlc.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_iso.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tlc.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tlc.shx
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_iso.prj
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tlc.shp
#   inflating: ../data/country_data/housekeeping/ne_admin_0_details_iso_countries.dbf
#   inflating: ../data/country_data/housekeeping/ne_admin_0_details_top_level_countries.dbf
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_iso.README.html
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tlc.VERSION.txt
#   inflating: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_tlc.README.html
#  extracting: ../data/country_data/10m_cultural/ne_10m_admin_0_countries_iso.VERSION.txt

# %% [markdown]
# ## FAO country data
# download from https://www.fao.org/faostat/en/#definitions. Press on the "Country/Region" button, then press "Download" and select "CSV" format. Rename the file to `FAOSTAT_country_definitions.csv` and put it in the file `data/country_data/FAOSTAT_country_definitions.csv` and put it in the file `data/country_data/FAOSTAT_country_definitions.csv`

# %% [markdown]
# # 3. Regions data

# %% [markdown]
# ## WWF ecoregions
#
# Get from https://www.worldwildlife.org/publications/terrestrial-ecoregions-of-the-world and unzip into the folder `data/regions_data/WWF_ecoregions`

# %% [markdown]
# ## GFED regions

# %%
# !wget "https://surfdrive.surf.nl/files/index.php/s/VPMEYinPeHtWVxn/download?path=%2Fmonthly&files=GFED5_Beta_monthly_2002.nc" -O ../data/regions_data/GFED/GFED5_Beta_monthly_2002.nc
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:34:52--  https://surfdrive.surf.nl/files/index.php/s/VPMEYinPeHtWVxn/download?path=%2Fmonthly&files=GFED5_Beta_monthly_2002.nc
# Resolving surfdrive.surf.nl (surfdrive.surf.nl)... 145.100.27.67, 145.107.56.140, 2001:610:108:203b:0:a11:da7a:5afe, ...
# Connecting to surfdrive.surf.nl (surfdrive.surf.nl)|145.100.27.67|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73681293 (70M) [application/octet-stream]
# Saving to: ‘../data/regions_data/GFED/GFED5_Beta_monthly_2002.nc’
#
# ../data/regions_dat 100%[===================>]  70.27M  24.2MB/s    in 2.9s
#
# 2025-03-04 10:34:56 (24.2 MB/s) - ‘../data/regions_data/GFED/GFED5_Beta_monthly_2002.nc’ saved [73681293/73681293]

# %% [markdown]
# ## [Xu et al. (2021)](https://www.science.org/doi/10.1126/sciadv.abe9829)

# %%
# !wget https://zenodo.org/records/4161694/files/global_ecoregions.tif?download=1 -O ../data/regions_data/xu_et_al_2021/global_ecoregions.tif
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:34:59--  https://zenodo.org/records/4161694/files/global_ecoregions.tif?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.45.92, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6768688 (6.5M) [image/tiff]
# Saving to: ‘../data/regions_data/xu_et_al_2021/global_ecoregions.tif’
#
# ../data/regions_dat 100%[===================>]   6.46M  2.54MB/s    in 2.5s
#
# 2025-03-04 10:35:02 (2.54 MB/s) - ‘../data/regions_data/xu_et_al_2021/global_ecoregions.tif’ saved [6768688/6768688]

# %% [markdown]
# # 4. Biomass data

# %% [markdown]
# ### [Liu et al. (2015)](https://www.nature.com/articles/nclimate2581)
#
# Download from http://wald.anu.edu.au/data_services/data/global-above-ground-biomass-carbon-v1-0/

# %%
# !wget https://www.dropbox.com/sh/1fo5q91v8rpwqtb/AAAE32d9FMrnG02wX8xuO8Fwa/Global_annual_mean_ABC_lc2001_1993_2012_20150331.nc?dl=0 -O ../data/biomass/liu_et_al_2015/Global_annual_mean_ABC_lc2001_1993_2012_20150331.nc
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:35:03--  https://www.dropbox.com/sh/1fo5q91v8rpwqtb/AAAE32d9FMrnG02wX8xuO8Fwa/Global_annual_mean_ABC_lc2001_1993_2012_20150331.nc?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fo/3n5d3tdltjk3wtiuc8s5q/AJW-OgBxYLczBNk-Tn9EvHg/Global_annual_mean_ABC_lc2001_1993_2012_20150331.nc?rlkey=kazzp3dvwj5h6kc4r7xlemy9i&dl=0 [following]
# --2025-03-04 10:35:03--  https://www.dropbox.com/scl/fo/3n5d3tdltjk3wtiuc8s5q/AJW-OgBxYLczBNk-Tn9EvHg/Global_annual_mean_ABC_lc2001_1993_2012_20150331.nc?rlkey=kazzp3dvwj5h6kc4r7xlemy9i&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com/cd/0/inline/ClPn0vkxrw2eQRzMdOsrq-YhYB06y3oiA0scPpyj4zsKo0ecR48KHYCEl1PP27EAamcafcxj7dLl8zbFu5WcjQJRzLimw9MXR8JB3pejYf0CuQIOhEvObZ4WkH16CjRVjUM/file# [following]
# --2025-03-04 10:35:04--  https://ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com/cd/0/inline/ClPn0vkxrw2eQRzMdOsrq-YhYB06y3oiA0scPpyj4zsKo0ecR48KHYCEl1PP27EAamcafcxj7dLl8zbFu5WcjQJRzLimw9MXR8JB3pejYf0CuQIOhEvObZ4WkH16CjRVjUM/file
# Resolving ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com (ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com)... 162.125.69.15, 2620:100:6021:15::a27d:410f
# Connecting to ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com (ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com)|162.125.69.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/ClOE4e5mxJg6a9-PUfzd_1c-abP9Jcps4NRF_FFAhNTqdyhKvyWbSOBvg5uEfGGTSN5JQ0yROiSLY8wufqtWGOKvEZ5LVDXcoE54CZRKMmRDX-rEL4vaAVbDiVz62o2ovOCP8L5ZpBJCY1ENJFggeesnu7UK2gyHrAFc5mkqQP7fkhHRf1n3VsOS47_F4zhOoeI-UCdrXnzP2J714fudGt3IGDWJsHGHcQkI5SdXFHEbjUTFjfoNk8GINs1yWpyM4p2-V-yjzjr4C0Hb846vEy25V4lWwsSvWEGiIhF-FHrdyBtrtTj61ELcTA7mNJNiUz_0410G6gpXqQzQcz_FiAw-KcKXGbNs_-PlCzJu0D8rWA/file [following]
# --2025-03-04 10:35:05--  https://ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com/cd/0/inline2/ClOE4e5mxJg6a9-PUfzd_1c-abP9Jcps4NRF_FFAhNTqdyhKvyWbSOBvg5uEfGGTSN5JQ0yROiSLY8wufqtWGOKvEZ5LVDXcoE54CZRKMmRDX-rEL4vaAVbDiVz62o2ovOCP8L5ZpBJCY1ENJFggeesnu7UK2gyHrAFc5mkqQP7fkhHRf1n3VsOS47_F4zhOoeI-UCdrXnzP2J714fudGt3IGDWJsHGHcQkI5SdXFHEbjUTFjfoNk8GINs1yWpyM4p2-V-yjzjr4C0Hb846vEy25V4lWwsSvWEGiIhF-FHrdyBtrtTj61ELcTA7mNJNiUz_0410G6gpXqQzQcz_FiAw-KcKXGbNs_-PlCzJu0D8rWA/file
# Reusing existing connection to ucbed4191522cb525ea134d0042e.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 33353704 (32M) [application/x-netcdf]
# Saving to: ‘../data/biomass/liu_et_al_2015/Global_annual_mean_ABC_lc2001_1993_2012_20150331.nc’
#
# ../data/biomass/liu 100%[===================>]  31.81M  20.7MB/s    in 1.5s
#
# 2025-03-04 10:35:07 (20.7 MB/s) - ‘../data/biomass/liu_et_al_2015/Global_annual_mean_ABC_lc2001_1993_2012_20150331.nc’ saved [33353704/33353704]

# %% [markdown]
# ### [Xu et al. (2021)](https://www.science.org/doi/10.1126/sciadv.abe9829)

# %%
# !wget https://zenodo.org/records/4161694/files/test10a_cd_ab_pred_corr_2000_2019_v2.tif?download=1 -O ../data/biomass/xu_et_al_2021/test10a_cd_ab_pred_corr_2000_2019_v2.tif
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:35:09--  https://zenodo.org/records/4161694/files/test10a_cd_ab_pred_corr_2000_2019_v2.tif?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.45.92, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 114424129 (109M) [image/tiff]
# Saving to: ‘../data/biomass/xu_et_al_2021/test10a_cd_ab_pred_corr_2000_2019_v2.tif’
#
# ../data/biomass/xu_ 100%[===================>] 109.12M  2.44MB/s    in 44s
#
# 2025-03-04 10:35:54 (2.48 MB/s) - ‘../data/biomass/xu_et_al_2021/test10a_cd_ab_pred_corr_2000_2019_v2.tif’ saved [114424129/114424129]

# %% [markdown]
# ### FRA data (Tubiello et al. 2021)

# %%
# !wget https://zenodo.org/records/3941973/files/GF_GHG_ForestLand_Total_2020_ZENODO.csv?download=1 -O ../data/biomass/tubiello_et_al_2021/GF_GHG_ForestLand_Total_2020_ZENODO.csv
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:35:57--  https://zenodo.org/records/3941973/files/GF_GHG_ForestLand_Total_2020_ZENODO.csv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9705116 (9.3M) [text/plain]
# Saving to: ‘../data/biomass/tubiello_et_al_2021/GF_GHG_ForestLand_Total_2020_ZENODO.csv’
#
# ../data/biomass/tub 100%[===================>]   9.25M  3.41MB/s    in 2.7s
#
# 2025-03-04 10:36:00 (3.41 MB/s) - ‘../data/biomass/tubiello_et_al_2021/GF_GHG_ForestLand_Total_2020_ZENODO.csv’ saved [9705116/9705116]

# %% [markdown]
# ### [Chen et al. (2023)](https://essd.copernicus.org/articles/15/897/2023/)
# From https://figshare.com/articles/dataset/1_km-resolution_maps_reveal_increases_in_above-_and_belowground_forest_biomass_carbon_pools_in_China_over_the_past_20_years/21931161/1

# %%
# !wget https://figshare.com/ndownloader/files/38902746 -O ../data/biomass/chen_et_al_2023/chen_et_al_2023.zip
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:36:07--  https://figshare.com/ndownloader/files/38902746
# Resolving figshare.com (figshare.com)... 52.19.53.149, 34.246.215.148, 2a05:d018:1f4:d000:3424:8425:de5c:b5b, ...
# Connecting to figshare.com (figshare.com)|52.19.53.149|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/38902746/DATA.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250304/eu-west-1/s3/aws4_request&X-Amz-Date=20250304T083608Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=871379f6f074393233900de40ccd2221ff426b0f210b03d44c5e9b62b53e1bdb [following]
# --2025-03-04 10:36:08--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/38902746/DATA.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250304/eu-west-1/s3/aws4_request&X-Amz-Date=20250304T083608Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=871379f6f074393233900de40ccd2221ff426b0f210b03d44c5e9b62b53e1bdb
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.92.35.176, 52.218.112.19, 52.218.28.99, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.92.35.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 940234313 (897M) [application/zip]
# Saving to: ‘../data/biomass/chen_et_al_2023/chen_et_al_2023.zip’
#
# ../data/biomass/che 100%[===================>] 896.68M  35.8MB/s    in 56s
#
# 2025-03-04 10:37:05 (15.9 MB/s) - ‘../data/biomass/chen_et_al_2023/chen_et_al_2023.zip’ saved [940234313/940234313]

# %%
# !unzip -o ../data/biomass/chen_et_al_2023/chen_et_al_2023.zip -d ../data/biomass/chen_et_al_2023/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Archive:  ../data/biomass/chen_et_al_2023/chen_et_al_2023.zip
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2002.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2003.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2004.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2005.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2006.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2007.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2008.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2009.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2010.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2011.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2012.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2013.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2014.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2015.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2016.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2017.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2018.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2019.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2020.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/AGBC/AGBCY2021.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2002.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2003.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2004.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2005.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2006.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2007.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2008.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2009.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2010.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2011.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2012.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2013.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2014.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2015.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2016.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2017.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2018.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2019.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2020.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/BGBC/BGBCY2021.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/FORESTLAND.tif
#   inflating: ../data/biomass/chen_et_al_2023/DATA/Readme.txt

# %% [markdown]
# ### Pan et al. (2024)
#
# Download from https://www.fs.usda.gov/rds/archive/products/RDS-2023-0051/RDS-2023-0051.zip

# %% [markdown]
# # 5. Aboveground to belowground biomass ratio data

# %% [markdown]
# ### [Ma et al. (2021)](https://www.nature.com/articles/s41559-021-01485-1)
#
# Save the data to GDrive - need to download it from GDrive after running the script into the directory `data/RMF/ma_et_al_2021/`.

# %%
# for each land cover type, export the root-to-shoot ratio map into GDrive
for type in ['forest','grass','shrub']:
    
    # get the image
    image = ee.Image(f"users/haozhima95/rootshootratio/{type}_rmf_map_mean_20200517")
    
    # get the crs and transform
    projection = image.select(0).projection().getInfo()
    crs = projection['crs']
    crs_transform = projection['transform']
    
    # Export the image, specifying the CRS, transform, and region.
    task = ee.batch.Export.image.toDrive(
        image=image,
        description=f'{type}_rmf_map_mean_20200517',
        crs=projection['crs'],
        crsTransform=projection['transform'],
        maxPixels=1e9
    )
    task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
    
# get the image
image = ee.Image('users/haozhima95/rootshootratio/rmf_all_20200521')

# get the crs and transform
projection = image.select(0).projection().getInfo()
crs = projection['crs']
crs_transform = projection['transform']

# Export the image, specifying the CRS, transform, and region.
task = ee.batch.Export.image.toDrive(
    image=image,
    description=f'rmf_all_20200517',
    crs=projection['crs'],
    crsTransform=projection['transform'],
    maxPixels=1e9
)
task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### [Huang et al. (2021)](https://essd.copernicus.org/articles/13/4263/2021/)

# %%
# !wget https://figshare.com/ndownloader/files/22432460 -O ../data/RMF/huang_et_al_2021/huang_et_al_2021.zip
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:40:22--  https://figshare.com/ndownloader/files/22432460
# Resolving figshare.com (figshare.com)... 34.246.215.148, 52.19.53.149, 2a05:d018:1f4:d000:3424:8425:de5c:b5b, ...
# Connecting to figshare.com (figshare.com)|34.246.215.148|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22432460/data_code_to_submit.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250304/eu-west-1/s3/aws4_request&X-Amz-Date=20250304T084022Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=07eb61bae5fb85e9782a57032a687b1d79e386543297418d84802146067c2234 [following]
# --2025-03-04 10:40:22--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22432460/data_code_to_submit.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250304/eu-west-1/s3/aws4_request&X-Amz-Date=20250304T084022Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=07eb61bae5fb85e9782a57032a687b1d79e386543297418d84802146067c2234
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 3.5.67.247, 52.92.3.184, 52.218.40.35, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|3.5.67.247|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 920394370 (878M) [application/zip]
# Saving to: ‘../data/RMF/huang_et_al_2021/huang_et_al_2021.zip’
#
# ../data/RMF/huang_e 100%[===================>] 877.76M  31.5MB/s    in 29s
#
# 2025-03-04 10:40:52 (30.2 MB/s) - ‘../data/RMF/huang_et_al_2021/huang_et_al_2021.zip’ saved [920394370/920394370]

# %%
# !unzip -o ../data/RMF/huang_et_al_2021/huang_et_al_2021.zip -d ../data/RMF/huang_et_al_2021/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Archive:  ../data/RMF/huang_et_al_2021/huang_et_al_2021.zip
#    creating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/budget_uncertainty.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/budget_uncertainty_propagate.xlsx
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/cal_15cover_globaltotal_99_a1.jnl
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/cal_15cover_globaltotal_99_a2.jnl
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/cal_15cover_globaltotal_99_a3.jnl
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/cal_15cover_globaltotal_99_a4.jnl
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/out_file_15_99_kfold1.dat
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/out_file_15_99_kfold2.dat
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/out_file_15_99_kfold3.dat
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/budget_uncertainty/out_file_15_99_kfold4.dat
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_merge_fill.py
#    creating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/baad_data.csv
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/Biomass_plot_DB.csv
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/Biomass_tree_DB.csv
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/China_forest.xlsx
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/Falster_et_al-2015-Ecology.pdf
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/Ledo_et_al-2018-New_Phytologist_tree_size_root.pdf
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/nph14863-sup-0002-notess1.xlsx
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/data_orin/sdata201770.pdf
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/environment_sensitivity_15cover_forFigure3_99_spearman_ave.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/err_bgb_15_99_ncomm_revise.nc
#    creating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS10_semivariogram_test.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS11_12_13_partial_dependence.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS14_plot_overestimation_smallscale_final.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS15_plot_overestimation_smallscale_funtional.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS16_plot_overestimation_smallscale_final_nosize.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS17_plot_overestimation_smallscale_funtional_nostructure.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS2_plot_geolocation_biomebackground.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS3_uncertainty.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS4_uncertainty_relative.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS5_predictor_distribution.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS6_predictor_space_evn_agb.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS7_biome_level_validate.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS8_seperate_validating.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/FigS9_continent_validation.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/Figure1_update.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/Figure2.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/fig/Figure3_enviroment_spearman.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/pergridarea_agb.nc
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/pergridarea_bgb.nc
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/pred_1km_15cover_1000_99.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/pred_1km_15cover_allometry_1000_99.py
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/ReadMe.docx
#   inflating: ../data/RMF/huang_et_al_2021/data_code_to_submit/site_filled_1kmv1.csv

# %% [markdown]
# # 6. Carbon budget data

# %% [markdown]
# ### Gbobal Carbon Budget 2023

# %%
# !wget https://globalcarbonbudgetdata.org/downloads/latest-data/Global_Carbon_Budget_2023v1.1.xlsx -O ../data/carbon_cycle/GCB/Global_Carbon_Budget_2023v1.1.xlsx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:42:09--  https://globalcarbonbudgetdata.org/downloads/latest-data/Global_Carbon_Budget_2023v1.1.xlsx
# Resolving globalcarbonbudgetdata.org (globalcarbonbudgetdata.org)... 52.222.144.14, 52.222.144.56, 52.222.144.28, ...
# Connecting to globalcarbonbudgetdata.org (globalcarbonbudgetdata.org)|52.222.144.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 415928 (406K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘../data/carbon_cycle/GCB/Global_Carbon_Budget_2023v1.1.xlsx’
#
# ../data/carbon_cycl 100%[===================>] 406.18K  2.55MB/s    in 0.2s
#
# 2025-03-04 10:42:09 (2.55 MB/s) - ‘../data/carbon_cycle/GCB/Global_Carbon_Budget_2023v1.1.xlsx’ saved [415928/415928]

# %% [markdown]
# ### Atmospheric inversion data
#
# Download GCB2023 data from https://meta.icos-cp.eu/objects/FHbD8OTgCb7Tlvs99lUDApO0 and copy it to the folder `data/carbon_cycle/atmospheric_inversions/`
#
# The reference is https://doi.org/10.18160/4M52-VCRU

# %% [markdown]
# # 7. DGVM data

# %%
# !wget https://zenodo.org/records/7598697/files/trendyv10_S3_cVeg_1901-2020_annual_gridded.nc?download=1 -O ../data/DGVMs/trendyv10_S3_cVeg_1901-2020_annual_gridded.nc
# !wget https://zenodo.org/records/7598697/files/trendyv10_S3_nbp_1901-2020_annual_gridded.nc?download=1 -O ../data/DGVMs/trendyv10_S3_nbp_1901-2020_annual_gridded.nc

# !wget https://zenodo.org/records/6884342/files/cVeg_S3.RData?download=1 -O ../data/DGVMs/cVeg_S3.RData
# !wget https://zenodo.org/records/6884342/files/nbp_S3.RData?download=1 -O ../data/DGVMs/nbp_S3.RData
# !wget https://zenodo.org/records/6884342/files/cSoil_S3.RData?download=1 -O ../data/DGVMs/cSoil_S3.RData
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:46:29--  https://zenodo.org/records/7598697/files/trendyv10_S3_cVeg_1901-2020_annual_gridded.nc?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 626354930 (597M) [application/octet-stream]
# Saving to: ‘../data/DGVMs/trendyv10_S3_cVeg_1901-2020_annual_gridded.nc’
#
# ../data/DGVMs/trend 100%[===================>] 597.34M  2.34MB/s    in 3m 44s
#
# 2025-03-04 10:50:14 (2.67 MB/s) - ‘../data/DGVMs/trendyv10_S3_cVeg_1901-2020_annual_gridded.nc’ saved [626354930/626354930]
#
# --2025-03-04 10:50:14--  https://zenodo.org/records/7598697/files/trendyv10_S3_nbp_1901-2020_annual_gridded.nc?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 626354930 (597M) [application/octet-stream]
# Saving to: ‘../data/DGVMs/trendyv10_S3_nbp_1901-2020_annual_gridded.nc’
#
# ../data/DGVMs/trend 100%[===================>] 597.34M  38.5MB/s    in 1m 46s
#
# 2025-03-04 10:52:00 (5.66 MB/s) - ‘../data/DGVMs/trendyv10_S3_nbp_1901-2020_annual_gridded.nc’ saved [626354930/626354930]
#
# --2025-03-04 10:52:01--  https://zenodo.org/records/6884342/files/cVeg_S3.RData?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16028 (16K) [application/octet-stream]
# Saving to: ‘../data/DGVMs/cVeg_S3.RData’
#
# ../data/DGVMs/cVeg_ 100%[===================>]  15.65K  --.-KB/s    in 0.07s
#
# 2025-03-04 10:52:01 (233 KB/s) - ‘../data/DGVMs/cVeg_S3.RData’ saved [16028/16028]
#
# --2025-03-04 10:52:01--  https://zenodo.org/records/6884342/files/nbp_S3.RData?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17569 (17K) [application/octet-stream]
# Saving to: ‘../data/DGVMs/nbp_S3.RData’
#
# ../data/DGVMs/nbp_S 100%[===================>]  17.16K  --.-KB/s    in 0.05s
#
# 2025-03-04 10:52:02 (347 KB/s) - ‘../data/DGVMs/nbp_S3.RData’ saved [17569/17569]
#
# --2025-03-04 10:52:02--  https://zenodo.org/records/6884342/files/cSoil_S3.RData?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15659 (15K) [application/octet-stream]
# Saving to: ‘../data/DGVMs/cSoil_S3.RData’
#
# ../data/DGVMs/cSoil 100%[===================>]  15.29K  --.-KB/s    in 0.01s
#
# 2025-03-04 10:52:02 (1.06 MB/s) - ‘../data/DGVMs/cSoil_S3.RData’ saved [15659/15659]

# %% [markdown]
# # 8. Data for supplementary analyses

# %% [markdown]
# ## FRA forest area

# %%
# !wget "https://fra-data.fao.org/api/file/data-download?assessmentName=fra&cycleName=2020&countryIso=WO&fileName=1_Forest_extent_characteristics_and_changes&fileType=xlsx&language=en" -O ../data/supplementary_analysis/forest_area/fra_2020.xlsx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:55:32--  https://fra-data.fao.org/api/file/data-download?assessmentName=fra&cycleName=2020&countryIso=WO&fileName=1_Forest_extent_characteristics_and_changes&fileType=xlsx&language=en
# Resolving fra-data.fao.org (fra-data.fao.org)... 104.18.10.41, 104.18.11.41, 2606:4700::6812:a29, ...
# Connecting to fra-data.fao.org (fra-data.fao.org)|104.18.10.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 910275 (889K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘../data/supplementary_analysis/forest_area/fra_2020.xlsx’
#
# ../data/supplementa 100%[===================>] 888.94K  3.50MB/s    in 0.2s
#
# 2025-03-04 10:55:33 (3.50 MB/s) - ‘../data/supplementary_analysis/forest_area/fra_2020.xlsx’ saved [910275/910275]

# %% [markdown]
# ## NFI data
#
# ### [Grassi et al. 2023](https://essd.copernicus.org/articles/15/1093/2023/)

# %%
# !wget "https://zenodo.org/records/7650360/files/National%20inventories%20LULUCF%20data%202000-2020%20(Dec%202022).xlsx?download=1" -O ../data/supplementary_analysis/NFI_data/National_inventories_LULUCF_data_2000-2020.xlsx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:55:35--  https://zenodo.org/records/7650360/files/National%20inventories%20LULUCF%20data%202000-2020%20(Dec%202022).xlsx?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 316119 (309K) [application/octet-stream]
# Saving to: ‘../data/supplementary_analysis/NFI_data/National_inventories_LULUCF_data_2000-2020.xlsx’
#
# ../data/supplementa 100%[===================>] 308.71K  1.16MB/s    in 0.3s
#
# 2025-03-04 10:55:36 (1.16 MB/s) - ‘../data/supplementary_analysis/NFI_data/National_inventories_LULUCF_data_2000-2020.xlsx’ saved [316119/316119]

# %% [markdown]
# ### [Grassi et al. 2022](https://essd.copernicus.org/articles/14/4643/2022/)

# %%
# !wget https://essd.copernicus.org/articles/14/4643/2022/essd-14-4643-2022-t05.xlsx -O ../data/supplementary_analysis/NFI_data/essd-14-4643-2022-t05.xlsx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:55:38--  https://essd.copernicus.org/articles/14/4643/2022/essd-14-4643-2022-t05.xlsx
# Resolving essd.copernicus.org (essd.copernicus.org)... 81.3.21.103
# Connecting to essd.copernicus.org (essd.copernicus.org)|81.3.21.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8226 (8.0K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘../data/supplementary_analysis/NFI_data/essd-14-4643-2022-t05.xlsx’
#
# ../data/supplementa 100%[===================>]   8.03K  --.-KB/s    in 0s
#
# 2025-03-04 10:55:38 (36.4 MB/s) - ‘../data/supplementary_analysis/NFI_data/essd-14-4643-2022-t05.xlsx’ saved [8226/8226]

# %% [markdown]
# ## Non-living carbon stock changes

# %% [markdown]
# ### Soil organic carbon stock losses

# %% [markdown]
# #### [Sanderman et a. (2017)](https://www.pnas.org/doi/full/10.1073/pnas.1706103114)

# %%
for file in ['SOCS_0_200cm_year_2010AD_10km.tif','SOCS_0_200cm_year_1990AD_10km.tif','SOCS_0_100cm_year_2010AD_10km.tif','SOCS_0_100cm_year_1990AD_10km.tif']:
    # !wget https://github.com/whrc/Soil-Carbon-Debt/raw/master/SOCS/{file} -O ../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/{file}
# !wget https://github.com/whrc/Soil-Carbon-Debt/raw/master/SOCS/SOCS_0_100cm_year_2010AD_10km.tif -O ../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_100cm_year_2010AD_10km.tif
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:55:42--  https://github.com/whrc/Soil-Carbon-Debt/raw/master/SOCS/SOCS_0_200cm_year_2010AD_10km.tif
# Resolving github.com (github.com)... 20.217.135.5
# Connecting to github.com (github.com)|20.217.135.5|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_200cm_year_2010AD_10km.tif [following]
# --2025-03-04 10:55:43--  https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_200cm_year_2010AD_10km.tif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3108314 (3.0M) [image/tiff]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_200cm_year_2010AD_10km.tif’
#
# ../data/supplementa 100%[===================>]   2.96M  11.2MB/s    in 0.3s
#
# 2025-03-04 10:55:43 (11.2 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_200cm_year_2010AD_10km.tif’ saved [3108314/3108314]
#
# --2025-03-04 10:55:44--  https://github.com/whrc/Soil-Carbon-Debt/raw/master/SOCS/SOCS_0_200cm_year_1990AD_10km.tif
# Resolving github.com (github.com)... 20.217.135.5
# Connecting to github.com (github.com)|20.217.135.5|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_200cm_year_1990AD_10km.tif [following]
# --2025-03-04 10:55:45--  https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_200cm_year_1990AD_10km.tif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3108269 (3.0M) [image/tiff]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_200cm_year_1990AD_10km.tif’
#
# ../data/supplementa 100%[===================>]   2.96M  11.0MB/s    in 0.3s
#
# 2025-03-04 10:55:45 (11.0 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_200cm_year_1990AD_10km.tif’ saved [3108269/3108269]
#
# --2025-03-04 10:55:46--  https://github.com/whrc/Soil-Carbon-Debt/raw/master/SOCS/SOCS_0_100cm_year_2010AD_10km.tif
# Resolving github.com (github.com)... 20.217.135.5
# Connecting to github.com (github.com)|20.217.135.5|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_100cm_year_2010AD_10km.tif [following]
# --2025-03-04 10:55:47--  https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_100cm_year_2010AD_10km.tif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2904101 (2.8M) [image/tiff]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_100cm_year_2010AD_10km.tif’
#
# ../data/supplementa 100%[===================>]   2.77M  10.4MB/s    in 0.3s
#
# 2025-03-04 10:55:47 (10.4 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_100cm_year_2010AD_10km.tif’ saved [2904101/2904101]
#
# --2025-03-04 10:55:48--  https://github.com/whrc/Soil-Carbon-Debt/raw/master/SOCS/SOCS_0_100cm_year_1990AD_10km.tif
# Resolving github.com (github.com)... 20.217.135.5
# Connecting to github.com (github.com)|20.217.135.5|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_100cm_year_1990AD_10km.tif [following]
# --2025-03-04 10:55:49--  https://raw.githubusercontent.com/whrc/Soil-Carbon-Debt/master/SOCS/SOCS_0_100cm_year_1990AD_10km.tif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2901860 (2.8M) [image/tiff]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_100cm_year_1990AD_10km.tif’
#
# ../data/supplementa 100%[===================>]   2.77M  10.4MB/s    in 0.3s
#
# 2025-03-04 10:55:50 (10.4 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/sanderman_et_al_2017/SOCS_0_100cm_year_1990AD_10km.tif’ saved [2901860/2901860]

# %% [markdown]
# #### [Houghton and Castanho (2023)](https://essd.copernicus.org/articles/15/2025/2023/)

# %%
# !wget https://essd.copernicus.org/articles/15/2025/2023/essd-15-2025-2023-t07.xlsx -O ../data/supplementary_analysis/nonliving_carbon/SOC_loss/houghton_castanho_2023/essd-15-2025-2023-t07.xlsx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:55:55--  https://essd.copernicus.org/articles/15/2025/2023/essd-15-2025-2023-t07.xlsx
# Resolving essd.copernicus.org (essd.copernicus.org)... 81.3.21.103
# Connecting to essd.copernicus.org (essd.copernicus.org)|81.3.21.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7557 (7.4K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/houghton_castanho_2023/essd-15-2025-2023-t07.xlsx’
#
# ../data/supplementa 100%[===================>]   7.38K  --.-KB/s    in 0s
#
# 2025-03-04 10:55:55 (1.04 GB/s) - ‘../data/supplementary_analysis/nonliving_carbon/SOC_loss/houghton_castanho_2023/essd-15-2025-2023-t07.xlsx’ saved [7557/7557]

# %% [markdown]
# ### Harvested wood products - [Johnston and Radeloff (2019)](https://www.pnas.org/doi/full/10.1073/pnas.1904231116)
#
# Download from https://www.pnas.org/doi/suppl/10.1073/pnas.1904231116/suppl_file/pnas.1904231116.sd01.xlsm and move to the folder `data/supplementary_analysis/nonliving_carbon/HWP/`

# %% [markdown]
# ### Artificial reservoirs

# %% [markdown]
# #### The GRanD v1.3 database
#
# From https://www.globaldamwatch.org/directory
#
# Download zip from https://ln.sync.com/dl/bd47eb6b0/anhxaikr-62pmrgtq-k44xf84f-pyz4atkm/view/default/447819520013 and move to `data/supplementary_analysis/nonliving_carbon/reservoirs/`

# %%
# !unzip -o ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3.zip -d ../data/supplementary_analysis/nonliving_carbon/reservoirs/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Archive:  ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3.zip
#    creating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_dams_v1_3.dbf
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_dams_v1_3.prj
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_dams_v1_3.sbn
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_dams_v1_3.sbx
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_dams_v1_3.shp
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_dams_v1_3.shx
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_reservoirs_v1_3.dbf
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_reservoirs_v1_3.prj
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_reservoirs_v1_3.sbn
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_reservoirs_v1_3.sbx
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_reservoirs_v1_3.shp
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_reservoirs_v1_3.shx
#   inflating: ../data/supplementary_analysis/nonliving_carbon/reservoirs/GRanD_Version_1_3/GRanD_Technical_Documentation_v1_3.pdf

# %% [markdown]
# #### [Mendonça et al. (2017)](https://www.nature.com/articles/s41467-017-01789-6)

# %%
# !wget https://static-content.springer.com/esm/art%3A10.1038%2Fs41467-017-01789-6/MediaObjects/41467_2017_1789_MOESM4_ESM.xlsx -O ../data/supplementary_analysis/nonliving_carbon/reservoirs/41467_2017_1789_MOESM4_ESM.xlsx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 10:59:56--  https://static-content.springer.com/esm/art%3A10.1038%2Fs41467-017-01789-6/MediaObjects/41467_2017_1789_MOESM4_ESM.xlsx
# Resolving static-content.springer.com (static-content.springer.com)... 199.232.80.95
# Connecting to static-content.springer.com (static-content.springer.com)|199.232.80.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 112833 (110K) [application/octet-stream]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/reservoirs/41467_2017_1789_MOESM4_ESM.xlsx’
#
# ../data/supplementa 100%[===================>] 110.19K  --.-KB/s    in 0.07s
#
# 2025-03-04 10:59:57 (1.62 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/reservoirs/41467_2017_1789_MOESM4_ESM.xlsx’ saved [112833/112833]

# %% [markdown]
# ### Landfills

# %% [markdown]
# #### Global waste production

# %%
# !wget https://datacatalogfiles.worldbank.org/ddh-published/0039597/DR0049199/country_level_data.csv?versionId=2024-06-05T14:35:21.1368563Z -O ../data/supplementary_analysis/nonliving_carbon/landfills/country_level_data.csv
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 11:00:01--  https://datacatalogfiles.worldbank.org/ddh-published/0039597/DR0049199/country_level_data.csv?versionId=2024-06-05T14:35:21.1368563Z
# Resolving datacatalogfiles.worldbank.org (datacatalogfiles.worldbank.org)... 13.107.246.62, 2620:1ec:bdf::62
# Connecting to datacatalogfiles.worldbank.org (datacatalogfiles.worldbank.org)|13.107.246.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35581 (35K) [text/csv]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/landfills/country_level_data.csv’
#
# ../data/supplementa 100%[===================>]  34.75K  --.-KB/s    in 0.02s
#
# 2025-03-04 11:00:03 (1.57 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/landfills/country_level_data.csv’ saved [35581/35581]

# %% [markdown]
# #### Global population

# %%
# !wget https://databank.worldbank.org/data/download/Population-Estimates_CSV.zip -O ../data/supplementary_analysis/nonliving_carbon/landfills/Population-Estimates_CSV.zip
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 11:00:04--  https://databank.worldbank.org/data/download/Population-Estimates_CSV.zip
# Resolving databank.worldbank.org (databank.worldbank.org)... 172.64.145.25, 104.18.42.231, 2606:4700:4400::ac40:9119, ...
# Connecting to databank.worldbank.org (databank.worldbank.org)|172.64.145.25|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://databankfiles.worldbank.org/public/ddpext_download/Population-Estimates_CSV.zip [following]
# --2025-03-04 11:00:05--  https://databankfiles.worldbank.org/public/ddpext_download/Population-Estimates_CSV.zip
# Resolving databankfiles.worldbank.org (databankfiles.worldbank.org)... 13.107.246.62, 2620:1ec:bdf::62
# Connecting to databankfiles.worldbank.org (databankfiles.worldbank.org)|13.107.246.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71717205 (68M) [application/octet-stream]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/landfills/Population-Estimates_CSV.zip’
#
# ../data/supplementa 100%[===================>]  68.39M  4.07MB/s    in 31s
#
# 2025-03-04 11:00:37 (2.19 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/landfills/Population-Estimates_CSV.zip’ saved [71717205/71717205]

# %%
# !unzip -o ../data/supplementary_analysis/nonliving_carbon/landfills/Population-Estimates_CSV.zip -d ../data/supplementary_analysis/nonliving_carbon/landfills/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Archive:  ../data/supplementary_analysis/nonliving_carbon/landfills/Population-Estimates_CSV.zip
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Population-EstimatesCSV.csv
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Population-EstimatesCountry.csv
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Population-EstimatesSeries.csv
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Population-Estimatescountry-series.csv
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Population-Estimatesfootnote.csv

# %% [markdown]
# #### WorldClim data

# %%
# !wget https://geodata.ucdavis.edu/climate/worldclim/2_1/base/wc2.1_10m_bio.zip -O ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio.zip
# !unzip -o ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio.zip -d ../data/supplementary_analysis/nonliving_carbon/landfills/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 11:00:59--  https://geodata.ucdavis.edu/climate/worldclim/2_1/base/wc2.1_10m_bio.zip
# Resolving geodata.ucdavis.edu (geodata.ucdavis.edu)... 128.120.146.30
# Connecting to geodata.ucdavis.edu (geodata.ucdavis.edu)|128.120.146.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49869449 (48M) [application/zip]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio.zip’
#
# ../data/supplementa 100%[===================>]  47.56M  12.2MB/s    in 4.3s
#
# 2025-03-04 11:01:04 (11.1 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio.zip’ saved [49869449/49869449]
#
# Archive:  ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio.zip
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_1.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_10.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_11.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_12.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_13.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_14.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_15.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_16.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_17.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_18.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_19.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_2.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_3.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_4.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_5.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_6.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_7.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_8.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/wc2.1_10m_bio_9.tif

# %% [markdown]
# #### Aridity Index data

# %%
# !wget https://figshare.com/ndownloader/files/34377245 -O ../data/supplementary_analysis/nonliving_carbon/landfills/AI_et0.zip
# !unzip -o ../data/supplementary_analysis/nonliving_carbon/landfills/AI_et0.zip -d ../data/supplementary_analysis/nonliving_carbon/landfills/
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 11:01:06--  https://figshare.com/ndownloader/files/34377245
# Resolving figshare.com (figshare.com)... 52.19.53.149, 34.246.215.148, 2a05:d018:1f4:d000:3424:8425:de5c:b5b, ...
# Connecting to figshare.com (figshare.com)|52.19.53.149|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/34377245/GlobalAI_ET0_annual_v3.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250304/eu-west-1/s3/aws4_request&X-Amz-Date=20250304T090107Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=27c85b382f4bb6fd2f4a686ddc54d6bee713216c48256fd7121a2a8a19d1e31e [following]
# --2025-03-04 11:01:07--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/34377245/GlobalAI_ET0_annual_v3.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250304/eu-west-1/s3/aws4_request&X-Amz-Date=20250304T090107Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=27c85b382f4bb6fd2f4a686ddc54d6bee713216c48256fd7121a2a8a19d1e31e
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.92.34.184, 52.218.37.139, 52.218.36.98, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.92.34.184|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797584309 (761M) [application/zip]
# Saving to: ‘../data/supplementary_analysis/nonliving_carbon/landfills/AI_et0.zip’
#
# ../data/supplementa 100%[===================>] 760.63M  19.9MB/s    in 44s
#
# 2025-03-04 11:01:51 (17.3 MB/s) - ‘../data/supplementary_analysis/nonliving_carbon/landfills/AI_et0.zip’ saved [797584309/797584309]
#
# Archive:  ../data/supplementary_analysis/nonliving_carbon/landfills/AI_et0.zip
#    creating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/ai_v3_yr.tfw
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/ai_v3_yr.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/ai_v3_yr.tif.aux.xml
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/ai_v3_yr.tif.xml
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr.tfw
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr.tif.aux.xml
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr.tif.vat.cpg
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr.tif.vat.dbf
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr.tif.xml
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr_sd.tfw
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr_sd.tif
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr_sd.tif.aux.xml
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr_sd.tif.vat.cpg
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr_sd.tif.vat.dbf
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/et0_v3_yr_sd.tif.xml
#   inflating: ../data/supplementary_analysis/nonliving_carbon/landfills/Global-AI_ET0_v3_annual/Global-AI_PET_v3 - Readme.pdf

# %% [markdown]
# ## Leaf biomass change

# %% [markdown]
# ### [Winkler et al. (2021)](https://bg.copernicus.org/articles/18/4985/2021/)

# %%
# !wget https://bg.copernicus.org/articles/18/4985/2021/bg-18-4985-2021-t02.xlsx -O ../data/supplementary_analysis/leaf_biomass_change/bg-18-4985-2021-t02.xlsx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 11:02:58--  https://bg.copernicus.org/articles/18/4985/2021/bg-18-4985-2021-t02.xlsx
# Resolving bg.copernicus.org (bg.copernicus.org)... 81.3.21.103
# Connecting to bg.copernicus.org (bg.copernicus.org)|81.3.21.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8183 (8.0K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘../data/supplementary_analysis/leaf_biomass_change/bg-18-4985-2021-t02.xlsx’
#
# ../data/supplementa 100%[===================>]   7.99K  --.-KB/s    in 0s
#
# 2025-03-04 11:02:58 (31.6 MB/s) - ‘../data/supplementary_analysis/leaf_biomass_change/bg-18-4985-2021-t02.xlsx’ saved [8183/8183]

# %% [markdown]
# ### [Butler et al. (2017)](https://www.pnas.org/doi/full/10.1073/pnas.1708984114)

# %%
# !wget https://github.com/abhirupdatta/global_maps_of_plant_traits/raw/master/sla/spat_1_superpft_sla_large.csv -O ../data/supplementary_analysis/leaf_biomass_change/spat_1_pft_sla_large.csv
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --2025-03-04 11:03:02--  https://github.com/abhirupdatta/global_maps_of_plant_traits/raw/master/sla/spat_1_superpft_sla_large.csv
# Resolving github.com (github.com)... 20.217.135.5
# Connecting to github.com (github.com)|20.217.135.5|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/abhirupdatta/global_maps_of_plant_traits/master/sla/spat_1_superpft_sla_large.csv [following]
# --2025-03-04 11:03:04--  https://raw.githubusercontent.com/abhirupdatta/global_maps_of_plant_traits/master/sla/spat_1_superpft_sla_large.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93961765 (90M) [text/plain]
# Saving to: ‘../data/supplementary_analysis/leaf_biomass_change/spat_1_pft_sla_large.csv’
#
# ../data/supplementa 100%[===================>]  89.61M  56.2MB/s    in 1.6s
#
# 2025-03-04 11:03:09 (56.2 MB/s) - ‘../data/supplementary_analysis/leaf_biomass_change/spat_1_pft_sla_large.csv’ saved [93961765/93961765]

# %% [markdown]
# ### MCD12C1.061
#
# Download from https://e4ftl01.cr.usgs.gov/MOTA/MCD12C1.061/2021.01.01/MCD12C1.A2021001.061.2022217040006.hdf and move to `data/supplementary_analysis/leaf_biomass_change/`
